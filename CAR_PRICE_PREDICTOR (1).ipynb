# %% [markdown]
# # **CAR PRICE PREDICTOR**
# #Task 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
cars=pd.read_csv('car data.csv')
cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Selling_Price'].plot(kind='hist', bins=20, title='Selling_Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Present_Price'].plot(kind='hist', bins=20, title='Present_Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Driven_kms'].plot(kind='hist', bins=20, title='Driven_kms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Car_Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Fuel_Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Year', y='Selling_Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Selling_Price', y='Present_Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Present_Price', y='Driven_kms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Selling_Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Car_Name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Car_Name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Selling_Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Selling_Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Fuel_Type')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Fuel_Type', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Selling_Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Present_Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Car_Name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Car_Name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Present_Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Present_Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Fuel_Type')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Fuel_Type', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Present_Price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Year'].plot(kind='line', figsize=(8, 4), title='Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Selling_Price'].plot(kind='line', figsize=(8, 4), title='Selling_Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Present_Price'].plot(kind='line', figsize=(8, 4), title='Present_Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Driven_kms'].plot(kind='line', figsize=(8, 4), title='Driven_kms')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Fuel_Type'].value_counts()
#     for x_label, grp in _df_17.groupby('Car_Name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Car_Name')
# _ = plt.ylabel('Fuel_Type')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['Car_Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Year', y='Car_Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Fuel_Type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Year', y='Fuel_Type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Car_Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Selling_Price', y='Car_Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['Fuel_Type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='Selling_Price', y='Fuel_Type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
cars['Selling_type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
cars['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
cars['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
cars['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
sns.countplot(x=cars['Fuel_Type'],data=cars,palette='hot')
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
sns.countplot(x=cars['Selling_type'],data=cars,palette='Accent_r')
# Out:
# <Axes: xlabel='Selling_type', ylabel='count'>

# %%
sns.countplot(x=cars['Transmission'],data=cars,palette='bone_r')
# Out:
# <Axes: xlabel='Transmission', ylabel='count'>

# %%
sns.countplot(x=cars['Year'],data=cars,palette='magma_r')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# # **Linear Regression**

# %%
#plotting a pairplot to understand multicollinearity
sns.pairplot(cars,x_vars=['Present_Price','Driven_kms'],y_vars='Selling_Price',size=4,aspect=1,kind='scatter')

# %%
#plotting a heatmap to understand correlation
sns.heatmap(cars.corr(), cmap = 'RdBu', annot = True )
# Out:
# <Axes: >

# %%
X=cars.Present_Price
Y=cars.Selling_Price
x1=X.to_numpy()
y1=Y.to_numpy()
x2=x1.reshape(-1,1)
y2=y1.reshape(-1,1)

# %%
#train test split to divide training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( x2, y2, train_size = 0.7, test_size = 0.3, random_state = 0 )

# %%
from sklearn.linear_model import LinearRegression
geek=LinearRegression()

# %%
geek.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#slope and intercept values of the linearRegression line
print(geek.intercept_)
print(geek.coef_)
# Out:
# [0.88095115]
# [[0.469235]]

# %%
y_pred=geek.predict(X_test)
from sklearn.metrics import mean_squared_error, r2_score
score=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
y_predu=geek.predict(X_train)
scoreX=r2_score(y_train,y_predu)
print("Root Mean Squared error value is:",rmse)
print("R^2 value for testing data:",score)
print("R^2 value for training data:",scoreX)
print("MSE cost function is:",mse)
# Out:
# Root Mean Squared error value is: 2.7913584863195067
# R^2 value for testing data: 0.7394613982313984
# R^2 value for training data: 0.7765662314248356
# MSE cost function is: 7.791682199147928

# %%
sns.regplot(x=cars['Present_Price'],y=cars['Selling_Price'])
# Out:
# <Axes: xlabel='Present_Price', ylabel='Selling_Price'>

# %%
plt.scatter(X_train, y_train,color='g')
plt.plot(X_test, y_pred,color='k')
plt.show()

# %% [markdown]
# # **Decision Tree**

# %%
#importing decision tree model
from sklearn.tree import DecisionTreeRegressor
dec=DecisionTreeRegressor(criterion='absolute_error')
dec.fit(X_train,y_train)
y_pred2=dec.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
score1=r2_score(y_test,y_pred2)
mse1=mean_squared_error(y_test,y_pred2)
rmse2=np.sqrt(mse1)
y_preds=dec.predict(X_train)
score2=r2_score(y_train,y_preds)
score2
print("Root Mean Sq error is: ", rmse2)
print("R^2 score for test data is: ", score1)
print("R^2 score for train data is: ", score2)
print("Mean Squared error is:", mse1)
# Out:
# Root Mean Sq error is:  3.1635301171630723
# R^2 score for test data is:  0.6653546504016985
# R^2 score for train data is:  0.9541455255212187
# Mean Squared error is: 10.007922802197802

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(90,50))
plot_tree(dec, feature_names = cars.Selling_Price,class_names= cars.Present_Price,filled=True);

# %% [markdown]
# # **Random Forest**

# %%
#importing Random forest model
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=40)
rf.fit(X_train,y_train)
y_pred_rf_test=rf.predict(X_test)
y_pred_rf_train= rf.predict(X_train)

# %%
score_rf_test=r2_score(y_test,y_pred_rf_test)
mse_rf=mean_squared_error(y_test,y_pred_rf_test)
rmse_rf=np.sqrt(mse_rf)
score_rf_train=r2_score(y_train,y_pred_rf_train)
print("Root Mean Sq error is: ", rmse_rf)
print("R^2 score for test data is: ", score_rf_test)
print("R^2 score for train data is: ", score_rf_train)
print("Mean Squared error is:", mse_rf)
# Out:
# Root Mean Sq error is:  3.1331203512362698
# R^2 score for test data is:  0.6717573556709252
# R^2 score for train data is:  0.9454995563152847
# Mean Squared error is: 9.816443135330886

# %% [markdown]
# # **XGBoost (Extreme Gradient Boosting)**

# %%
#importing Extreme Gradient Boosting model
import xgboost as xgb
sexy=xgb.XGBRegressor()
sexy.fit(X_train,y_train)
y_pred_xgb_test=sexy.predict(X_test)
y_pred_xgb_train= sexy.predict(X_train)

# %%
score_xgb_test=r2_score(y_test,y_pred_xgb_test)
mse_xgb=mean_squared_error(y_test,y_pred_xgb_test)
rmse_xgb=np.sqrt(mse_xgb)
score_xgb_train=r2_score(y_train,y_pred_xgb_train)
print("Root Mean Sq error is: ", rmse_xgb)
print("R^2 score for test data is: ", score_xgb_test)
print("R^2 score for train data is: ", score_xgb_train)
print("Mean Squared error is:", mse_xgb)
# Out:
# Root Mean Sq error is:  3.3557104500485093
# R^2 score for test data is:  0.6234611358339122
# R^2 score for train data is:  0.9609633420251601
# Mean Squared error is: 11.260792624564768

# %% [markdown]
# # **ADABoost (Adaptive Boosting)**

# %%
#importing Adaptive Boosting model with base estimator : Linear regression
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor(base_estimator=geek)

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=LinearRegression())

# %%
y_pred_ada_test=ada.predict(X_test)
y_pred_ada_train= ada.predict(X_train)

# %%
score_ada_test=r2_score(y_test,y_pred_ada_test)
mse_ada=mean_squared_error(y_test,y_pred_ada_test)
rmse_ada=np.sqrt(mse_ada)
score_ada_train=r2_score(y_train,y_pred_ada_train)
print("Root Mean Sq error is: ", rmse_ada)
print("R^2 score for test data is: ", score_ada_test)
print("R^2 score for train data is: ", score_ada_train)
print("Mean Squared error is:", mse_ada)
# Out:
# Root Mean Sq error is:  2.7409466769662116
# R^2 score for test data is:  0.7487870514225803
# R^2 score for train data is:  0.7653741448313779
# Mean Squared error is: 7.512788685972119

# %% [markdown]
# # **Concise Summary**

# %%
#cumulative summary of r^2 values of train and test data of each model
models = pd.DataFrame({ 'Model': ['Linear Regressor', 'Decision Tree Regressor', 'ADABoost Regressor','Random Forest Regressor', 'XGBoost Regressor'],
                       'Training R2_Score': [scoreX,score2,score_ada_train,score_rf_train,score_xgb_train],

                       'Testing R2_Score': [score,score1,score_ada_test,score_rf_test,score_xgb_test]})
models.sort_values(by = ['Training R2_Score', 'Testing R2_Score'], ascending = False, ignore_index = True)
# Out:
#                      Model  Training R2_Score  Testing R2_Score
# 0        XGBoost Regressor           0.960963          0.623461
# 1  Decision Tree Regressor           0.954146          0.665355
# 2  Random Forest Regressor           0.945500          0.671757
# 3         Linear Regressor           0.776566          0.739461
# 4       ADABoost Regressor           0.765374          0.748787

# %% [markdown]
# # **Hyperparameter Tuning on Random Forest Model**

# %%
from sklearn.model_selection import GridSearchCV
params={'max_depth':[2,3,5,10,20],
        'min_samples_leaf':[5,10,20,50,100,200],
        'n_estimators':[10,25,30,50,100,200]}

# %%
grid_search=GridSearchCV(estimator=rf,param_grid=params,cv=4,n_jobs=-1,scoring='accuracy')
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestRegressor(n_estimators=40), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy')

# %%
best_param=grid_search.best_params_
best_param
# Out:
# {'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}

# %%
regression_rf=RandomForestRegressor(max_depth=2,min_samples_leaf=5,n_estimators=10,oob_score=True)

# %%
regression_rf.fit(X_train,y_train)
regression_rf.oob_score_
# Out:
# 0.7368959318231136

# %%
y_pred_hyper_test=regression_rf.predict(X_test)
y_pred_hyper_train= regression_rf.predict(X_train)

# %%
score_reg_rf_test=r2_score(y_test,y_pred_hyper_test)
mse_reg_rf=mean_squared_error(y_test,y_pred_hyper_test)
rmse_reg_rf=np.sqrt(mse_reg_rf)
score_reg_rf_train=r2_score(y_train,y_pred_hyper_train)
print("Root Mean Sq error is: ", rmse_reg_rf)
print("R^2 score for test data is: ", score_reg_rf_test)
print("R^2 score for train data is: ", score_reg_rf_train)
print("Mean Squared error is:", mse_reg_rf)
# Out:
# Root Mean Sq error is:  2.847841752401508
# R^2 score for test data is:  0.7288106979173443
# R^2 score for train data is:  0.8147323449569088
# Mean Squared error is: 8.110202646721293

# %% [markdown]
# **The Hyperparameter tuning action using GridSearchCV resulted in an improved R2 score of 0.72 for the test data.**
# ***Thank You!***
